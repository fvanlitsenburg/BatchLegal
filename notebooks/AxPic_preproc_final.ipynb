# %% [markdown]
# # BatchLegal Preprocessing

# %% [markdown]
# ***Base***: preproc final (from Chris):
# - Adjusted preprocessing steps: sentence tokenization and multiple lemmatizing steps.
# - Changed from CountVectorizer to TfidfVectorizer
# - Now spacy is used for lemmatization

# %%
# !pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (4.62.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (0.7.7)
# Requirement already satisfied: packaging>=20.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (0.9.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: jinja2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (3.0.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (1.0.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (1.18.5)
# Requirement already satisfied: setuptools in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (56.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (1.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (2.4.3)
# Requirement already satisfied: pathy>=0.3.5 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (0.6.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy) (8.0.16)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from packaging>=20.0->spacy) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (4.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from jinja2->spacy) (2.0.1)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 14.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: setuptools in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (56.0.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.2)
# Requirement already satisfied: jinja2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.62.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.27.1)
# Requirement already satisfied: pathy>=0.3.5 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: numpy>=1.15.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.18.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.16)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.7)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/axelpichler/.pyenv/versions/3.8.13/envs/lewagon/lib/python3.8/site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.1)
# WARNING: There was an error checking the latest version of pip.
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#Imports

import pandas as pd
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from nltk.collocations import *

import spacy

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
#Loading data from csv
data = pd.read_csv("data_19_rows.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Date of document', 'Title', 'Subtitle', 'CELEX number',
#        'EUROVOC descriptor', 'Subject matter', 'Directory code', 'Author',
#        'In force indicator', 'Content'],
#       dtype='object')

# %%
df_content = data.Content

# %%
# Prepared function to later integrate notebook into .py files 
# def get_content(data):
#     return data.content

# %%
df_content.head()
# Out:
# 0     (1) Pursuant to Articles 9 and 168 of the Tre...
# 1     (1) The objective of the Union’s policy on as...
# 2     (1) The development of health technologies is...
# 3     (1) The Commission communication of 29 Novemb...
# 4     (1) The Commission communication of 29 Novemb...
# Name: Content, dtype: object

# %%
# list used to remove unrelevant terms 
ignore_list = {'ec', 'no', 'european', 'commission', 'eu', 'union',
                   'article', 'directive', 'council', 'regulation', 'official',
                   'journal', 'article', 'information', 'agency', 'regulation',
                   'mssg', 'data', 'member', 'states', 'etf', 'mdssg', 'shall'
                  }

# %%
def cleaning(sentence):
    
    # Basic cleaning
    sentence = sentence.strip() ## remove whitespaces
    sentence = sentence.lower() ## lowercasing 
    sentence = ''.join(char for char in sentence if not char.isdigit()) ## removing numbers
    
    # Advanced cleaning
    for punctuation in string.punctuation:
        sentence = sentence.replace(punctuation, '') ## removing punctuation
    tokenized_sentence = word_tokenize(sentence) ## tokenizing 
    stop_words = set(stopwords.words('english')) ## defining stopwords
    tokenized_sentence_cleaned = [w for w in tokenized_sentence 
                                  if not w in stop_words] ## remove stopwords
    
    #tokenized_sentence_cleaned = [w for w in tokenized_sentence_cleaned if not w in ignore_list] COMMENTED IGNORE OUT!
    
    sentences = ' '.join(word for word in tokenized_sentence_cleaned)
    
    #spacy
    nlp = spacy.load('en_core_web_sm', disable=["parser"])

    doc = nlp(sentences)
    lemmatized = " ".join([token.lemma_ for token in doc])
    
    return lemmatized

# %%
# Applying Davy's Function

clean_txt = df_content.apply(cleaning)

# %%
#Checking outcome of Preprocessing
clean_txt
# Out:
# 0     pursuant article treaty function european unio...
# 1     objective union ' policy asylum develop establ...
# 2     development health technology key driver econo...
# 3     commission communication november entitle ' fu...
# 4     commission communication november entitle ' fu...
# 5     technical difficulty breed due complex genetic...
# 6     agreement withdrawal united kingdom great brit...
# 7     regulation eu european parliament council expi...
# 8     december commission adopt communication entitl...
# 9     directive ec european parliament council lay r...
# 10    regulation ec european parliament council subs...
# 11    context evolve migratory challenge characteris...
# 12    union ' objective ensure high level security w...
# 13    national security remain solely competence mem...
# 14    order achieve smart sustainable inclusive grow...
# 15    european maritime fishery aquaculture fund ' e...
# 16    existential threat pose climate change require...
# 17    customs office situate external border union n...
# 18    article treaty function european union tfeu pr...
# 19    article treaty function european union tfeu pr...
# Name: Content, dtype: object

# %%
clean_txt[0]
# Out:
# "pursuant article treaty function european union ' tfeu ' article charter fundamental right european union ' charter ' union ensure high level human health protection definition implementation union policy activity covid pandemic highlighted interconnectedness human animal ecosystem health risk pose loss biodiversity earth recognise world health organization many microbe infect animal human effort focus human health animal health prevent eliminate problem disease transmission disease may transmit human animal vice versa therefore need tackle human animal take advantage potential synergy research treatment approximately emerge disease almost know pandemic namely influenza hivaid covid zoonoses disease increase globally past year change land use deforestation urbanisation agricultural expansion intensification wildlife traffic consumption pattern factor contribute increase zoonotic pathogen bacterial viral parasitic include unconventional agent able spread human direct contact food water environment covid pandemic clear example need reinforce application one health approach union achieve well public health outcome since state regulation eu european parliament council ' human health connect animal health environment … action tackle threat health must take account three dimension ' unprecedented experience covid pandemic also highlight difficulty union member state address public health emergency regard demonstrate need strengthen union ' role order effective manage availability medicinal product availability medical device vitro diagnostic medical device respective accessory collectively ' medical device ' develop medical countermeasure address threat pose public health early stage harmonise way ensure cooperation coordination union national regional competent authority medicinal product medical device industry actor supply chain medicinal product medical device include healthcare professional union need give high priority health ability ensure continue provision high quality healthcare service prepare address pandemics health threat severely impede absence clearly define legal framework manage response pandemics limit mandate resource health agency well limited degree union member states preparedness public health emergency impact majority member state shortage medicinal product medical device different complex root cause need map understand analyse together different stakeholder order comprehensively address well understanding shortage include identification vulnerability supply chain specific case covid pandemic shortage treatment disease variety cause range production difficulty third country logistical production difficulty within union shortage vaccine due inadequate manufacturing capacity disruption often complex supply chain medicinal product medical device national export restriction ban border closure impede free movement good uncertainty relate supply demand good context covid pandemic lack production union certain medicinal product active substance lead significant impediment smooth function internal market address serious threat public health across union serious consequence union ' citizen address issue shortage medicinal product longstande priority member states european parliament illustrate several report european parliament european parliament resolution september shortage medicine – address emerge problem well discussion within council european union however issue remain date unaddresse shortage medicinal product represent grow threat public health serious impact healthcare system right patient access appropriate medical treatment increase global demand medicinal product exacerbate covid pandemic lead shortage medicinal product weaken healthcare system member state pose significant risk patient ' health care patient particularly term disease progression worsen symptom long delay interruption care therapy long period hospitalisation increase risk exposure falsify medicinal product medication error adverse effect ...

# %%
# bigram vectorization

vectorizer_n_gram = TfidfVectorizer(ngram_range = (1,1)) # BI-GRAMS
cleaned_vectorizer_n_gram = vectorizer_n_gram.fit_transform(clean_txt)

# %%
# function for integration to .py file later
# def vectorizer(clean_txt):
#     vectorizer_n_gram = TfidfVectorizer(ngram_range = (1,1)) # BI-GRAMS
#     cleaned_vectorizer_n_gram = vectorizer_n_gram.fit_transform(clean_txt)
#     return cleaned_vectorizer_n_gram

# %%
df = pd.DataFrame(cleaned_vectorizer_n_gram.toarray(), columns=vectorizer_n_gram.get_feature_names_out())
